# %% [markdown]
# # Biography Text Ablation Analysis
#
# To understand why the LLM is able to predict race so effectively, we performed an ablation analysis by replacing salient keywords with generic terms (e.g. "Ang Lee" is replaced with "PERSON", "Venezuela" is replaced with "LOCATION") and observing how model performance changes. We focus on `names` (was the model trained on these people, so it has background information from pre-training), `location` (does the model have priors about what races tend to be concentrated in what locations?), and `ethnicity` (does it recognize explicit race-related information in the bio).

# %% [markdown]
# ## Relabel Named Entities with Flair
#
# We use `Flair`, a well-known Named Entity Recognition (NER) library to relabel named entities in the biography text. We relabel 1) names, 2) locations, 3) ethnicities, as well as combinations of the three together.

# %%
import pandas as pd
import sys
sys.path.append("../script")
from BiographyAblation import FlairHelper
from tqdm.notebook import tqdm
tqdm.pandas()

root_dir = ".."
df = pd.read_csv(f"{root_dir}/data/cleaned_final_sample_metadata.csv", header=0) # if needed to read in
df["bio"] = df["bio"].astype(str)
flair = FlairHelper()
# Out:
# 2023-09-07 23:50:46,999 SequenceTagger predicts: Dictionary with 75 tags: O, S-PERSON, B-PERSON, E-PERSON, I-PERSON, S-GPE, B-GPE, E-GPE, I-GPE, S-ORG, B-ORG, E-ORG, I-ORG, S-DATE, B-DATE, E-DATE, I-DATE, S-CARDINAL, B-CARDINAL, E-CARDINAL, I-CARDINAL, S-NORP, B-NORP, E-NORP, I-NORP, S-MONEY, B-MONEY, E-MONEY, I-MONEY, S-PERCENT, B-PERCENT, E-PERCENT, I-PERCENT, S-ORDINAL, B-ORDINAL, E-ORDINAL, I-ORDINAL, S-LOC, B-LOC, E-LOC, I-LOC, S-TIME, B-TIME, E-TIME, I-TIME, S-WORK_OF_ART, B-WORK_OF_ART, E-WORK_OF_ART, I-WORK_OF_ART, S-FAC

# %%
df.head(1)

# %%
# NON-ETHNICITY ENTITIES

df["flair_ethn_bio"] = df["bio"].progress_apply(lambda x: flair.label_specific_entities(x, flair.entities["ethnicity"]))

# NON-LOCATION ENTITIES
df["flair_loc_bio"] = df["bio"].progress_apply(lambda x: flair.label_specific_entities(x, flair.entities["location"]))

# NON-PERSON ENTITIES
df["flair_ppl_bio"] = df["bio"].progress_apply(lambda x: flair.label_specific_entities(x, flair.entities["people"]))
# Out:
#   0%|          | 0/5201 [00:00<?, ?it/s]

# %%
file = "flair_bios.csv"
df.to_csv(f"{root_dir}/data/{file}", index=False)

# %%
# ETHNICITY AND PERSON ENTITIES
df["flair_ethn+ppl_bio"] = df["bio"].progress_apply(lambda x: flair.label_specific_entities(x, flair.entities["ethnicity+people"]))

# ETHNICITY AND LOCATION ENTITIES
df["flair_ethn+loc_bio"] = df["bio"].progress_apply(lambda x: flair.label_specific_entities(x, flair.entities["ethnicity+location"]))

# LOCATION AND PERSON ENTITIES
df["flair_loc+ppl_bio"] = df["bio"].progress_apply(lambda x: flair.label_specific_entities(x, flair.entities["location+people"]))
# Out:
#   0%|          | 0/5201 [00:00<?, ?it/s]
#   0%|          | 0/5201 [00:00<?, ?it/s]
#   0%|          | 0/5201 [00:00<?, ?it/s]

# %%
file = "flair_bios.csv"
df.to_csv(f"{root_dir}/data/{file}", index=False)

# %%
# ETHNICITY AND LOCATION AND PERSON ENTITIES
df["flair_ethn+loc+ppl_bio"] = df["bio"].progress_apply(lambda x: flair.label_specific_entities(x, flair.entities["ethnicity+location+people"]))
# Out:
#   0%|          | 0/5201 [00:00<?, ?it/s]

# %%
file = "flair_bios.csv"
df.to_csv(f"{root_dir}/data/{file}", index=False)

# %% [markdown]
# ## Relabel person names with regular expressions

# %%
import pandas as pd
import sys
sys.path.append("../script")
from BiographyAblation import FlairHelper
from tqdm.notebook import tqdm
tqdm.pandas()

root_dir = ".."
file = "flair_bios.csv"

df = pd.read_csv(f"{root_dir}/data/{file}")
df["bio"] = df["bio"].astype(str)
flair = FlairHelper()
# Out:
# 2023-09-09 20:36:28.461319: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-09 20:38:03,926 SequenceTagger predicts: Dictionary with 75 tags: O, S-PERSON, B-PERSON, E-PERSON, I-PERSON, S-GPE, B-GPE, E-GPE, I-GPE, S-ORG, B-ORG, E-ORG, I-ORG, S-DATE, B-DATE, E-DATE, I-DATE, S-CARDINAL, B-CARDINAL, E-CARDINAL, I-CARDINAL, S-NORP, B-NORP, E-NORP, I-NORP, S-MONEY, B-MONEY, E-MONEY, I-MONEY, S-PERCENT, B-PERCENT, E-PERCENT, I-PERCENT, S-ORDINAL, B-ORDINAL, E-ORDINAL, I-ORDINAL, S-LOC, B-LOC, E-LOC, I-LOC, S-TIME, B-TIME, E-TIME, I-TIME, S-WORK_OF_ART, B-WORK_OF_ART, E-WORK_OF_ART, I-WORK_OF_ART, S-FAC

# %%
# PERSON ITSELF ONLY (removes only person name but keeps mentions of others)
df["flair_person_only_bio"] = df.progress_apply(lambda x: flair.label_name_as_keyword(string=x["bio"], 
                                                                                      name=x["name"],
                                                                                      keyword="PERSON"
                                                                                      ), axis=1)
# Out:
#   0%|          | 0/5201 [00:00<?, ?it/s]

# %%
df["flair_ethn_bio"] = df["flair_ethn_bio"].astype(str)
df["flair_loc_bio"] = df["flair_loc_bio"].astype(str)
df["flair_ethn+loc_bio"] = df["flair_ethn+loc_bio"].astype(str)

# PERSON ITSELF ONLY (removes only person name but keeps mentions of others)
df["flair_person+ethn_bio"] = df.progress_apply(lambda x: flair.label_name_as_keyword(string=x["flair_ethn_bio"], 
                                                                                      name=x["name"],
                                                                                      keyword="PERSON"
                                                                                      ), axis=1)

# PERSON ITSELF ONLY (removes only person name but keeps mentions of others)
df["flair_person+loc_bio"] = df.progress_apply(lambda x: flair.label_name_as_keyword(string=x["flair_loc_bio"], 
                                                                                      name=x["name"],
                                                                                      keyword="PERSON"
                                                                                      ), axis=1)

# PERSON ITSELF ONLY (removes only person name but keeps mentions of others)
df["flair_person+ethn+loc_bio"] = df.progress_apply(lambda x: flair.label_name_as_keyword(string=x["flair_ethn+loc_bio"], 
                                                                                      name=x["name"],
                                                                                      keyword="PERSON"
                                                                                      ), axis=1)
# Out:
#   0%|          | 0/5201 [00:00<?, ?it/s]
#   0%|          | 0/5201 [00:00<?, ?it/s]
#   0%|          | 0/5201 [00:00<?, ?it/s]

# %%
file = "flair_bios.csv"
df.to_csv(f"{root_dir}/data/{file}", index=False)

# %%
df.head()
# Out:
#             name             href   race       role  \
# 0        Ang Lee  /name/nm0000487  Asian  Filmmaker
# 1      James Wan  /name/nm1490123  Asian  Filmmaker
# 2     Jon M. Chu  /name/nm0160840  Asian  Filmmaker
# 3  Taika Waititi  /name/nm0169806  Asian  Filmmaker
# 4   Karyn Kusama  /name/nm0476201  Asian  Filmmaker
#
#                                                image  \
# 0  https://m.media-amazon.com/images/M/MV5BODA2MT...
# 1  https://m.media-amazon.com/images/M/MV5BMTY5Nz...
# 2  https://m.media-amazon.com/images/M/MV5BNDM0Nj...
# 3  https://m.media-amazon.com/images/M/MV5BMzk4MD...
# 4  https://m.media-amazon.com/images/M/MV5BMTUzMT...
#
#                                                  bio  \
# 0  Born in 1954 in Pingtung, Taiwan, Ang Lee has ...
# 1  James Wan (born 26 February 1977) is an Austra...
# 2  Jon is an alumni of the USC School of Cinema-T...
# 3  Taika Waititi, also known as Taika Cohen, hail...
# 4  Karyn Kusama was born on March 21, 1968 in Bro...
#
#                                     bio_preprocessed  \
# 0  bear pingtung taiwan ang lee today great conte...
# 1  james wan bear february australian film produc...
# 2  jon alumnus usc school cinema television win p...
# 3  taika waititi know taika cohen hail raukokore ...
# 4  karyn kusama bear march brooklyn new york usa ...
#
#                                       flair_ethn_bio  \
# 0  Born in 1954 in Pingtung , Taiwan , Ang Lee ha...
# 1  James Wan ( born 26 February 1977 ) is an NORP...
# 2  Jon is an alumni of the USC School of Cinema-T...
# 3  Taika Waititi , also known as Taika Cohen , ha...
# 4  Karyn Kusama was born on March 21 , 1968 in Br...
#
#                                        flair_loc_bio  \
# 0  Born in 1954 in GPE , GPE , Ang Lee has become...
# 1  James Wan ( born 26 February 1977 ) is an Aust...
# 2  Jon is an alumni of the USC School of Cinema-T...
# 3  Taika Waititi , also known as Taika Cohen , ha...
# 4  Karyn Kusama was born on March 21 , 1968 in GP...
#
#                                        flair_ppl_bio  \
# 0  Born in 1954 in Pingtung , Taiwan , PERSON has...
# 1  PERSON ( born 26 February 1977 ) is an Austral...
# 2  PERSON is an alumni of the USC School of Cinem...
# 3  PERSON , also known as PERSON , hails from the...
# 4  PERSON was born on March 21 , 1968 in Brooklyn...
#
#                                   flair_ethn+ppl_bio  \
# 0  Born in 1954 in Pingtung , Taiwan , PERSON has...
# 1  PERSON ( born 26 February 1977 ) is an NORP fi...
# 2  PERSON is an alumni of the USC School of Cinem...
# 3  PERSON , also known as PERSON , hails from the...
# 4  PERSON was born on March 21 , 1968 in Brooklyn...
#
#                                   flair_ethn+loc_bio  \
# 0  Born in 1954 in GPE , GPE , Ang Lee has become...
# 1  James Wan ( born 26 February 1977 ) is an NORP...
# 2  Jon is an alumni of the USC School of Cinema-T...
# 3  Taika Waititi , also known as Taika Cohen , ha...
# 4  Karyn Kusama was born on March 21 , 1968 in GP...
#
#                                    flair_loc+ppl_bio  \
# 0  Born in 1954 in GPE , GPE , PERSON has become ...
# 1  PERSON ( born 26 February 1977 ) is an Austral...
# 2  PERSON is an alumni of the USC School of Cinem...
# 3  PERSON , also known as PERSON , hails from the...
# 4  PERSON was born on March 21 , 1968 in GPE , GP...
#
#                               flair_ethn+loc+ppl_bio  \
# 0  Born in 1954 in GPE , GPE , PERSON has become ...
# 1  PERSON ( born 26 February 1977 ) is an NORP fi...
# 2  PERSON is an alumni of the USC School of Cinem...
# 3  PERSON , also known as PERSON , hails from the...
# 4  PERSON was born on March 21 , 1968 in GPE , GP...
#
#                                flair_person_only_bio  \
# 0  Born in 1954 in Pingtung, Taiwan, PERSON has b...
# 1  PERSON (born 26 February 1977) is an Australia...
# 2  PERSON is an alumni of the USC School of Cinem...
# 3  PERSON, also known as PERSON Cohen, hails from...
# 4  PERSON was born on March 21, 1968 in Brooklyn,...
#
#                                flair_person+ethn_bio  \
# 0  Born in 1954 in Pingtung , Taiwan , PERSON has...
# 1  PERSON ( born 26 February 1977 ) is an NORP fi...
# 2  PERSON is an alumni of the USC School of Cinem...
# 3  PERSON , also known as PERSON Cohen , hails fr...
# 4  PERSON was born on March 21 , 1968 in Brooklyn...
#
#                                 flair_person+loc_bio  \
# 0  Born in 1954 in GPE , GPE , PERSON has become ...
# 1  PERSON ( born 26 February 1977 ) is an Austral...
# 2  PERSON is an alumni of the USC School of Cinem...
# 3  PERSON , also known as PERSON Cohen , hails fr...
# 4  PERSON was born on March 21 , 1968 in GPE , GP...
#
#                            flair_person+ethn+loc_bio
# 0  Born in 1954 in GPE , GPE , PERSON has become ...
# 1  PERSON ( born 26 February 1977 ) is an NORP fi...
# 2  PERSON is an alumni of the USC School of Cinem...
# 3  PERSON , also known as PERSON Cohen , hails fr...
# 4  PERSON was born on March 21 , 1968 in GPE , GP...

# %% [markdown]
# We use `flair_bios.csv` to make predictions in `BioAblationTesting.ipynb` (hosted on CoLab with our BioRaceBERT models). After testing is complete, we use the file `flair_bios_probs.csv`here to continue our analysis!

# %% [markdown]
# # Ablation Analysis Results

# %%
import pandas as pd
import numpy as np

root_dir = ".."
file = "flair_bios_probs.csv"

df = pd.read_csv(f"{root_dir}/data/ablation/{file}")
df.head()

# transform str to numpy arr
for column in df.loc[:, "flair_ethn_bio_probs":"flair_person+ethn+loc_bio_probs"].columns:
    print(column)
    df[column] = df[column].apply(lambda x: np.fromstring(x.replace('\n','').replace('[','')
                                                .replace(']','').replace('  ',' '), sep=' '))
# Out:
# flair_ethn_bio_probs
# flair_ppl_bio_probs
# flair_loc_bio_probs
# flair_ethn+loc_bio_probs
# flair_loc+ppl_bio_probs
# flair_ethn+ppl_bio_probs
# flair_ethn+loc+ppl_bio_probs
# flair_person_only_bio_probs
# flair_person+ethn_bio_probs
# flair_person+loc_bio_probs
# flair_person+ethn+loc_bio_probs

# %%
# transform probs to preds
for column in df.loc[:, "flair_ethn_bio_probs":"flair_person+ethn+loc_bio_probs"].columns:
    pred_column = column[:-5]+"pred"
    print(pred_column)
    df[pred_column] = df[column].apply(np.argmax)
# Out:
# flair_ethn_bio_pred
# flair_ppl_bio_pred
# flair_loc_bio_pred
# flair_ethn+loc_bio_pred
# flair_loc+ppl_bio_pred
# flair_ethn+ppl_bio_pred
# flair_ethn+loc+ppl_bio_pred
# flair_person_only_bio_pred
# flair_person+ethn_bio_pred
# flair_person+loc_bio_pred
# flair_person+ethn+loc_bio_pred

# %%
df.head()
# Out:
#    val_index           name             href   race  race_cat  \
# 0          4   Karyn Kusama  /name/nm0476201  Asian         0
# 1         12    Michael Aki  /name/nm0406866  Asian         0
# 2         13       Tze Chun  /name/nm2309735  Asian         0
# 3         23  Jon Moritsugu  /name/nm0605748  Asian         0
# 4         39     Arvin Chen  /name/nm1789897  Asian         0
#
#                                                  bio  \
# 0  Karyn Kusama was born on March 21, 1968 in Bro...
# 1  Michael Aki is known for Strangers (2012), Sun...
# 2  Tze Chun was born in 1980 in Chicago, Illinois...
# 3  Jon Moritsugu was born in Honolulu, Hawaii and...
# 4  Arvin Chen was born on November 26, 1978 in Bo...
#
#                                flair_ethn_bio_probs  \
# 0  [0.89769673, 0.05522941, 0.02654695, 0.02052698]
# 1   [0.18161274, 0.7488212, 0.05243589, 0.01713014]
# 2  [0.99025285, 0.00470042, 0.00267916, 0.00236759]
# 3   [0.9827559, 0.00791049, 0.00380127, 0.00553237]
# 4  [0.99072254, 0.00457601, 0.00260002, 0.00210143]
#
#                                 flair_ppl_bio_probs  \
# 0    [0.15194972, 0.3393335, 0.11186691, 0.3968498]
# 1    [0.04335849, 0.899591, 0.03256469, 0.02448585]
# 2  [0.12482573, 0.34341195, 0.08811145, 0.44365084]
# 3    [0.45687556, 0.15597484, 0.0341593, 0.3529903]
# 4   [0.4317788, 0.34700966, 0.11402743, 0.10718403]
#
#                                 flair_loc_bio_probs  \
# 0  [0.90568954, 0.05156705, 0.02243588, 0.02030754]
# 1   [0.18161274, 0.7488212, 0.05243589, 0.01713014]
# 2  [0.99141055, 0.00423765, 0.00232041, 0.00203141]
# 3   [0.96962756, 0.01498768, 0.00535408, 0.0100307]
# 4    [0.991614, 0.00414406, 0.00234378, 0.00189816]
#
#                            flair_ethn+loc_bio_probs  ... flair_ppl_bio_pred  \
# 0  [0.90568954, 0.05156705, 0.02243588, 0.02030754]  ...                  3
# 1   [0.18161274, 0.7488212, 0.05243589, 0.01713014]  ...                  1
# 2  [0.99141055, 0.00423765, 0.00232041, 0.00203141]  ...                  3
# 3   [0.96962756, 0.01498768, 0.00535408, 0.0100307]  ...                  0
# 4    [0.991614, 0.00414406, 0.00234378, 0.00189816]  ...                  0
#
#   flair_loc_bio_pred flair_ethn+loc_bio_pred flair_loc+ppl_bio_pred  \
# 0                  0                       0                      3
# 1                  1                       1                      1
# 2                  0                       0                      1
# 3                  0                       0                      3
# 4                  0                       0                      1
#
#   flair_ethn+ppl_bio_pred flair_ethn+loc+ppl_bio_pred  \
# 0                       3                           3
# 1                       1                           1
# 2                       3                           1
# 3                       0                           3
# 4                       0                           1
#
#   flair_person_only_bio_pred  flair_person+ethn_bio_pred  \
# 0                          3                           3
# 1                          1                           1
# 2                          3                           3
# 3                          3                           3
# 4                          0                           0
#
#    flair_person+loc_bio_pred  flair_person+ethn+loc_bio_pred
# 0                          3                               3
# 1                          1                               1
# 2                          3                               3
# 3                          3                               3
# 4                          0                               0
#
# [5 rows x 28 columns]

# %%
from sklearn.metrics import classification_report

report = ""
# transform probs to preds
for column in df.loc[:, "flair_ethn_bio_pred":"flair_person+ethn+loc_bio_pred"].columns:
    report += f"{column}\n"
    report += classification_report(df["race_cat"], df[column])
    report += "\n"
    
with open(f"{root_dir}/data/full_report.txt", "w") as file:
    file.write(report)

# %% [markdown]
# In the `BioAblationBreakdown` notebook, we found that 2000 people in our dataset contain bios with name, ethnicity, and location. To see how removing salient terms affects the model without diluting the differences with bios that do not contain these tags, we do this again with the 2000 only.

# %%
import pandas as pd
import numpy as np

root_dir = ".."

df = pd.read_csv(f"{root_dir}/data/ablation/flair_bios_probs.csv")
df2 = pd.read_csv(f"{root_dir}/data/BioRaceBERT-final.csv")
df2 = df2[["href", "pred", "pred_cat"]]
df = df.merge(df2, how="left", on=["href"])

subset = pd.read_csv(f"{root_dir}/data/ablation/flair_ethn_loc_ppl_tags.csv")
subset = subset.merge(df, how="left", on=["name", "href"])

# transform str to numpy arr
for column in subset.loc[:, "flair_ethn_bio_probs":"flair_person+ethn+loc_bio_probs"].columns:
    subset[column] = subset[column].apply(lambda x: np.fromstring(x.replace('\n','').replace('[','')
                                                .replace(']','').replace('  ',' '), sep=' '))

print(f"{len(subset)} bios contain ethnicity, location, and name tags")
# Out:
# 2000 bios contain ethnicity, location, and name tags

# %%
# transform probs to preds
for column in subset.loc[:, "flair_ethn_bio_probs":"flair_person+ethn+loc_bio_probs"].columns:
    pred_column = column[:-5]+"pred"
    print(pred_column)
    subset[pred_column] = subset[column].apply(np.argmax)
    
subset.head()
# Out:
# flair_ethn_bio_pred
# flair_ppl_bio_pred
# flair_loc_bio_pred
# flair_ethn+loc_bio_pred
# flair_loc+ppl_bio_pred
# flair_ethn+ppl_bio_pred
# flair_ethn+loc+ppl_bio_pred
# flair_person_only_bio_pred
# flair_person+ethn_bio_pred
# flair_person+loc_bio_pred
# flair_person+ethn+loc_bio_pred
#                     name             href  val_index   race  race_cat  \
# 0                Ang Lee  /name/nm0000487          0  Asian         0
# 1              James Wan  /name/nm1490123          1  Asian         0
# 2          Taika Waititi  /name/nm0169806          3  Asian         0
# 3  Destin Daniel Cretton  /name/nm2308774          5  Asian         0
# 4     Cary Joji Fukunaga  /name/nm1560977          6  Asian         0
#
#                                                  bio  \
# 0  Born in 1954 in Pingtung, Taiwan, Ang Lee has ...
# 1  James Wan (born 26 February 1977) is an Austra...
# 2  Taika Waititi, also known as Taika Cohen, hail...
# 3  Destin Daniel Cretton is an American filmmaker...
# 4  Cary Joji Fukunaga is a Japanese-American film...
#
#                                 flair_ethn_bio_probs  \
# 0  [0.99847263, 0.00066385587, 0.00051732763, 0.0...
# 1  [0.99908316, 0.00035026207, 0.00029325642, 0.0...
# 2  [0.99753428, 0.00071190548, 0.00029314714, 0.0...
# 3  [0.99937469, 0.00031833138, 7.7739089e-05, 0.0...
# 4  [0.99862421, 0.00054787938, 0.00066704396, 0.0...
#
#                                  flair_ppl_bio_probs  \
# 0  [0.99842072, 0.00068193884, 0.00055345672, 0.0...
# 1  [0.99937797, 0.00023431388, 0.0002744417, 0.00...
# 2     [0.9690823, 0.0099647, 0.00503781, 0.01591518]
# 3  [0.99985337, 6.7081281e-05, 2.2032673e-05, 5.7...
# 4  [0.9992494, 0.00027673534, 0.00037278712, 0.00...
#
#                                  flair_loc_bio_probs  \
# 0  [0.99819928, 0.00081236725, 0.00061019597, 0.0...
# 1  [0.99940217, 0.00022724959, 0.00025402274, 0.0...
# 2  [0.99798477, 0.00054067979, 0.00042303358, 0.0...
# 3  [0.99982005, 8.1814796e-05, 2.5762196e-05, 7.2...
# 4  [0.99916244, 0.00029407119, 0.00040605458, 0.0...
#
#                             flair_ethn+loc_bio_probs  ... flair_ppl_bio_pred  \
# 0  [0.9978981, 0.0010070485, 0.00066028308, 0.000...  ...                  0
# 1  [0.99910283, 0.00035023357, 0.00028576891, 0.0...  ...                  0
# 2  [0.99894899, 0.00043529656, 0.00015622516, 0.0...  ...                  0
# 3     [0.13964729, 0.8090083, 0.00675368, 0.0445907]  ...                  0
# 4  [0.99865985, 0.00063580065, 0.00054617401, 0.0...  ...                  0
#
#   flair_loc_bio_pred flair_ethn+loc_bio_pred flair_loc+ppl_bio_pred  \
# 0                  0                       0                      0
# 1                  0                       0                      0
# 2                  0                       0                      0
# 3                  0                       1                      0
# 4                  0                       0                      0
#
#   flair_ethn+ppl_bio_pred flair_ethn+loc+ppl_bio_pred  \
# 0                       0                           0
# 1                       3                           3
# 2                       3                           0
# 3                       0                           1
# 4                       1                           1
#
#   flair_person_only_bio_pred flair_person+ethn_bio_pred  \
# 0                          0                          0
# 1                          0                          3
# 2                          0                          3
# 3                          0                          0
# 4                          0                          3
#
#    flair_person+loc_bio_pred  flair_person+ethn+loc_bio_pred
# 0                          0                               0
# 1                          0                               3
# 2                          0                               3
# 3                          0                               0
# 4                          0                               3
#
# [5 rows x 30 columns]

# %%
from sklearn.metrics import classification_report

report = ""
# transform probs to preds
for column in subset.loc[:, "pred_cat":"flair_person+ethn+loc_bio_pred"].columns:
    print(column)
    report += f"{column}\n"
    report += classification_report(subset["race_cat"], subset[column])
    report += "\n"
    print(classification_report(subset["race_cat"], subset[column]))
# Out:
# pred_cat
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       460
#            1       0.97      0.93      0.95       329
#            2       0.98      0.98      0.98       425
#            3       0.97      0.99      0.98       786
#
#     accuracy                           0.97      2000
#    macro avg       0.97      0.97      0.97      2000
# weighted avg       0.97      0.97      0.97      2000
#
# flair_ethn_bio_pred
#               precision    recall  f1-score   support
#
#            0       0.97      0.92      0.94       460
#            1       0.88      0.86      0.87       329
#            2       0.95      0.93      0.94       425
#            3       0.93      0.98      0.96       786
#
#     accuracy                           0.94      2000
#    macro avg       0.93      0.92      0.93      2000
# weighted avg       0.94      0.94      0.93      2000
#
# flair_ppl_bio_pred
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.93       460
#            1       0.76      0.94      0.84       329
#            2       0.95      0.89      0.92       425
#            3       0.95      0.91      0.93       786
#
#     accuracy                           0.91      2000
#    macro avg       0.90      0.91      0.90      2000
# weighted avg       0.92      0.91      0.91      2000
#
# flair_loc_bio_pred
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97       460
#            1       0.94      0.93      0.93       329
#            2       0.97      0.95      0.96       425
#            3       0.95      0.98      0.97       786
#
#     accuracy                           0.96      2000
#    macro avg       0.96      0.96      0.96      2000
# weighted avg       0.96      0.96      0.96      2000
#
# flair_ethn+loc_bio_pred
#               precision    recall  f1-score   support
#
#            0       0.96      0.86      0.91       460
#            1       0.81      0.87      0.83       329
#            2       0.95      0.87      0.90       425
#            3       0.90      0.97      0.94       786
#
#     accuracy                           0.91      2000
#    macro avg       0.90      0.89      0.90      2000
# weighted avg       0.91      0.91      0.91      2000
#
# flair_loc+ppl_bio_pred
#               precision    recall  f1-score   support
#
#            0       0.95      0.85      0.90       460
#            1       0.66      0.95      0.78       329
#            2       0.97      0.82      0.89       425
#            3       0.92      0.88      0.90       786
#
#     accuracy                           0.87      2000
#    macro avg       0.87      0.88      0.87      2000
# weighted avg       0.89      0.87      0.88      2000
#
# flair_ethn+ppl_bio_pred
#               precision    recall  f1-score   support
#
#            0       0.90      0.74      0.81       460
#            1       0.51      0.88      0.65       329
#            2       0.95      0.68      0.80       425
#            3       0.87      0.84      0.85       786
#
#     accuracy                           0.79      2000
#    macro avg       0.81      0.78      0.78      2000
# weighted avg       0.84      0.79      0.80      2000
#
# flair_ethn+loc+ppl_bio_pred
#               precision    recall  f1-score   support
#
#            0       0.89      0.54      0.67       460
#            1       0.38      0.92      0.54       329
#            2       0.96      0.44      0.60       425
#            3       0.82      0.77      0.79       786
#
#     accuracy                           0.67      2000
#    macro avg       0.76      0.67      0.65      2000
# weighted avg       0.79      0.67      0.68      2000
#
# flair_person_only_bio_pred
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95       460
#            1       0.85      0.93      0.89       329
#            2       0.97      0.92      0.95       425
#            3       0.95      0.97      0.96       786
#
#     accuracy                           0.94      2000
#    macro avg       0.94      0.94      0.94      2000
# weighted avg       0.94      0.94      0.94      2000
#
# flair_person+ethn_bio_pred
#               precision    recall  f1-score   support
#
#            0       0.94      0.78      0.85       460
#            1       0.67      0.86      0.75       329
#            2       0.94      0.80      0.87       425
#            3       0.88      0.93      0.91       786
#
#     accuracy                           0.86      2000
#    macro avg       0.86      0.84      0.85      2000
# weighted avg       0.87      0.86      0.86      2000
#
# flair_person+loc_bio_pred
#               precision    recall  f1-score   support
#
#            0       0.97      0.90      0.93       460
#            1       0.81      0.94      0.87       329
#            2       0.97      0.88      0.92       425
#            3       0.93      0.95      0.94       786
#
#     accuracy                           0.92      2000
#    macro avg       0.92      0.92      0.92      2000
# weighted avg       0.93      0.92      0.92      2000
#
# flair_person+ethn+loc_bio_pred
#               precision    recall  f1-score   support
#
#            0       0.92      0.64      0.76       460
#            1       0.55      0.88      0.68       329
#            2       0.94      0.69      0.80       425
#            3       0.85      0.91      0.88       786
#
#     accuracy                           0.80      2000
#    macro avg       0.82      0.78      0.78      2000
# weighted avg       0.84      0.80      0.80      2000

# %%
print(report)
with open(f"{root_dir}/data/subset_report.txt", "w") as file:
    file.write(report)
# Out:
# pred_cat
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       460
#            1       0.97      0.93      0.95       329
#            2       0.98      0.98      0.98       425
#            3       0.97      0.99      0.98       786
#
#     accuracy                           0.97      2000
#    macro avg       0.97      0.97      0.97      2000
# weighted avg       0.97      0.97      0.97      2000
#
# flair_ethn_bio_pred
#               precision    recall  f1-score   support
#
#            0       0.97      0.92      0.94       460
#            1       0.88      0.86      0.87       329
#            2       0.95      0.93      0.94       425
#            3       0.93      0.98      0.96       786
#
#     accuracy                           0.94      2000
#    macro avg       0.93      0.92      0.93      2000
# weighted avg       0.94      0.94      0.93      2000
#
# flair_ppl_bio_pred
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.93       460
#            1       0.76      0.94      0.84       329
#            2       0.95      0.89      0.92       425
#            3       0.95      0.91      0.93       786
#
#     accuracy                           0.91      2000
#    macro avg       0.90      0.91      0.90      2000
# weighted avg       0.92      0.91      0.91      2000
#
# flair_loc_bio_pred
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97       460
#            1       0.94      0.93      0.93       329
#            2       0.97      0.95      0.96       425
#            3       0.95      0.98      0.97       786
#
#     accuracy                           0.96      2000
#    macro avg       0.96      0.96      0.96      2000
# weighted avg       0.96      0.96      0.96      2000
#
# flair_ethn+loc_bio_pred
#               precision    recall  f1-score   support
#
#            0       0.96      0.86      0.91       460
#            1       0.81      0.87      0.83       329
#            2       0.95      0.87      0.90       425
#            3       0.90      0.97      0.94       786
#
#     accuracy                           0.91      2000
#    macro avg       0.90      0.89      0.90      2000
# weighted avg       0.91      0.91      0.91      2000
#
# flair_loc+ppl_bio_pred
#               precision    recall  f1-score   support
#
#            0       0.95      0.85      0.90       460
#            1       0.66      0.95      0.78       329
#            2       0.97      0.82      0.89       425
#            3       0.92      0.88      0.90       786
#
#     accuracy                           0.87      2000
#    macro avg       0.87      0.88      0.87      2000
# weighted avg       0.89      0.87      0.88      2000
#
# flair_ethn+ppl_bio_pred
#               precision    recall  f1-score   support
#
#            0       0.90      0.74      0.81       460
#            1       0.51      0.88      0.65       329
#            2       0.95      0.68      0.80       425
#            3       0.87      0.84      0.85       786
#
#     accuracy                           0.79      2000
#    macro avg       0.81      0.78      0.78      2000
# weighted avg       0.84      0.79      0.80      2000
#
# flair_ethn+loc+ppl_bio_pred
#               precision    recall  f1-score   support
#
#            0       0.89      0.54      0.67       460
#            1       0.38      0.92      0.54       329
#            2       0.96      0.44      0.60       425
#            3       0.82      0.77      0.79       786
#
#     accuracy                           0.67      2000
#    macro avg       0.76      0.67      0.65      2000
# weighted avg       0.79      0.67      0.68      2000
#
# flair_person_only_bio_pred
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95       460
#            1       0.85      0.93      0.89       329
#            2       0.97      0.92      0.95       425
#            3       0.95      0.97      0.96       786
#
#     accuracy                           0.94      2000
#    macro avg       0.94      0.94      0.94      2000
# weighted avg       0.94      0.94      0.94      2000
#
# flair_person+ethn_bio_pred
#               precision    recall  f1-score   support
#
#            0       0.94      0.78      0.85       460
#            1       0.67      0.86      0.75       329
#            2       0.94      0.80      0.87       425
#            3       0.88      0.93      0.91       786
#
#     accuracy                           0.86      2000
#    macro avg       0.86      0.84      0.85      2000
# weighted avg       0.87      0.86      0.86      2000
#
# flair_person+loc_bio_pred
#               precision    recall  f1-score   support
#
#            0       0.97      0.90      0.93       460
#            1       0.81      0.94      0.87       329
#            2       0.97      0.88      0.92       425
#            3       0.93      0.95      0.94       786
#
#     accuracy                           0.92      2000
#    macro avg       0.92      0.92      0.92      2000
# weighted avg       0.93      0.92      0.92      2000
#
# flair_person+ethn+loc_bio_pred
#               precision    recall  f1-score   support
#
#            0       0.92      0.64      0.76       460
#            1       0.55      0.88      0.68       329
#            2       0.94      0.69      0.80       425
#            3       0.85      0.91      0.88       786
#
#     accuracy                           0.80      2000
#    macro avg       0.82      0.78      0.78      2000
# weighted avg       0.84      0.80      0.80      2000

# %% [markdown]
# ### The performance is still very high, even after dropping these labels... why is this happening?
#
# We save the 2000 bios to a file in order to understand what other attributes are relevant. Visit `BioAblationTesting` to see the results of looking through it (planning to use LIME here).

# %%
df = pd.read_csv(f"{root_dir}/data/flair_bios.csv")
subset = subset.loc[:,"name": "href"]
subset = subset.merge(df, how="left", on=["name", "href"])
subset.to_csv(f"{root_dir}/data/flair_bios_subset.csv")
print(len(subset))
# Out:
# 2000
